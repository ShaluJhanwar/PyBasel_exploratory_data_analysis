# %%
# Import the neccessary modules for data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as matplot
import seaborn as sns

# %matplotlib inline

# %%
a = [2, 1]
b = [3, 4]
plt.plot(a, b)
plt.show()
